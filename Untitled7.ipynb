# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
data = pd.read_excel(r"C:\Users\admin\Downloads\netflix1.xlsx")
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
import pandas as pd
data = pd.read_excel(r"C:\Users\admin\Downloads\netflix1.xlsx")
print(data.info())
print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   datetime64[ns]
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 686.8+ KB
# None
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
#Check the first few rows of data:
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
#Check for unique values in certain columns (for example, type or rating):
print(data['type'].unique())  # Shows unique types (e.g., Movie, TV Show)
print(data['rating'].unique())  # Shows unique ratings (e.g., PG, R, etc.)
# Out:
# ['Movie' 'TV Show']
# ['PG-13' 'TV-MA' 'TV-PG' 'TV-14' 'TV-Y7' 'TV-Y' 'PG' 'TV-G' 'R' 'G'
#  'NC-17' 'NR' 'TV-Y7-FV' 'UR']

# %%
# Check records for a few different years
print(data[data['release_year'] == 2020].shape)
print(data[data['release_year'] == 2019].shape)
# Out:
# (953, 10)
# (1030, 10)

# %%
#Summary statistics for numeric columns (e.g., release_year):
data.describe()
# Out:
#                           date_added  release_year
# count                           8790   8790.000000
# mean   2019-05-17 21:44:01.638225408   2014.183163
# min              2008-01-01 00:00:00   1925.000000
# 25%              2018-04-06 00:00:00   2013.000000
# 50%              2019-07-03 00:00:00   2017.000000
# 75%              2020-08-19 18:00:00   2019.000000
# max              2021-09-25 00:00:00   2021.000000
# std                              NaN      8.825466

# %%
#Sort the data (e.g., by release year or title):
data_sorted = data.sort_values(by='release_year', ascending=False)
print(data_sorted.head())
# Out:
#      show_id     type                                            title  \
# 7355   s2921  TV Show                                    Love Is Blind
# 28       s24    Movie     Go! Go! Cory Carson: Chrissy Takes the Wheel
# 27       s21  TV Show  Monsters Inside: The 24 Faces of Billy Milligan
# 24       s12  TV Show                                 Bangkok Breaking
# 23        s7    Movie                 My Little Pony: A New Generation
#
#                            director        country date_added  release_year  \
# 7355                      Not Given  United States 2020-02-13          2021
# 28          Alex Woo, Stanley Moore  United States 2021-09-21          2021
# 27                  Olivier Megaton  United States 2021-09-22          2021
# 24                Kongkiat Komesiri      Not Given 2021-09-23          2021
# 23    Robert Cullen, José Luis Ucha      Not Given 2021-09-24          2021
#
#      rating  duration                                          listed_in
# ...

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.0 MB 5.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.0 MB 5.8 MB/s eta 0:00:01
#    ------------------ --------------------- 3.7/8.0 MB 5.9 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.0 MB 5.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 5.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.2 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 6.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
# ...

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count plot of genres (assuming genres are in 'listed_in')
sns.countplot(x="listed_in", data=data)
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %%
rating_counts = data['rating'].value_counts()
print(rating_counts)
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
# Create a mapping for ratings (this is just an example) numpy
rating_map = {
    'G': 1,
    'PG': 2,
    'PG-13': 3,
    'R': 4,
    'NC-17': 5
}

# Map the 'rating' column to numeric values
rating_numeric = data['rating'].map(rating_map)

# Convert the mapped ratings to a NumPy array
rating_array = np.array(rating_numeric)

# Calculate the average rating
avg_rating = np.nanmean(rating_array)  # Using np.nanmean to ignore NaN values if any
print(f"Average rating (numeric scale): {avg_rating}")
# Out:
# Average rating (numeric scale): 3.269135802469136
